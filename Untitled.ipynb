# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard

# %%
dir_file = 'data/train/'
class_category = ['cats','dogs']

# %%
for category in class_category: # there are to categories, dogs and cats
    path = os.path.join(dir_file,category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_array,cmap = 'gray')
        plt.show()
        break
    break
print(img_array)
# Out:
# [[167 167 168 ... 204 203 202]
#  [167 167 168 ... 204 203 203]
#  [167 167 168 ... 205 204 203]
#  ...
#  [124 124 124 ...   2   2   2]
#  [123 123 123 ...   1   1   1]
#  [122 122 123 ...   1   1   1]]

# %%
IMG_SIZE = 50
new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_array, cmap='gray')
plt.show()
new_array = cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
plt.imshow(new_array, cmap='gray')
plt.show()
training_data = []

# %%
def create_training_data():
    for category in class_category:
        path = os.path.join(dir_file,category)
        class_num = class_category.index(category)
        for img in tqdm(os.listdir(path)):
            try:
                img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                training_data.append([new_array, class_num])
            except Exception as e:
                pass
create_training_data()
print(len(training_data))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 184/184 [00:00<00:00, 1008.88it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 201/201 [00:00<00:00, 873.06it/s]
# 768

# %%
import random
random.shuffle(training_data)
for sample in training_data[:10]:
    print(sample[1])

X = []
y = []

for features,label in training_data:
    X.append(features)
    y.append(label)
print(X[0].reshape(-1, IMG_SIZE,IMG_SIZE,1))

X = np.array(X).reshape(-1, IMG_SIZE,IMG_SIZE,1)
# Out:
# 0
# 1
# 1
# 1
# 0
# 0
# 1
# 0
# 1
# 1
# [[[[146]
#    [144]
#    [145]
#    ...
#    [144]
#    [148]
#    [144]]
#
#   [[145]
#    [151]
#    [154]
#    ...
#    [148]
#    [144]
#    [142]]
#
#   [[151]
#    [149]
#    [154]
#    ...
#    [141]
#    [148]
#    [144]]
#
#   ...
#
#   [[138]
#    [133]
#    [144]
#    ...
#    [151]
#    [148]
#    [145]]
#
#   [[139]
#    [145]
#    [144]
#    ...
#    [147]
#    [148]
#    [138]]
#
#   [[140]
#    [133]
#    [135]
#    ...
#    [151]
#    [148]
#    [146]]]]

# %%
import pickle

pickle_out = open("X.pickle","wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle","wb")
pickle.dump(y, pickle_out)
pickle_out.close()

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

y = np.array(y)
dense_layers = [0]
layer_sizes = [64]
conv_layers = [3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)

            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())

            for _ in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))

            model.add(Dense(1))
            model.add(Activation('sigmoid'))

            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

            model.compile(loss='binary_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          )

            model.fit(X, 
                      y,
                      batch_size=32,
                      epochs=25,
                      validation_split=0.3,
                      callbacks=[tensorboard])

model.save('Cat_vs_Dog-CNN.model')
# Out:
# 3-conv-64-nodes-0-dense-1610026641
# Epoch 1/25
# 17/17 [==============================] - 3s 137ms/step - loss: 0.6971 - accuracy: 0.4621 - val_loss: 0.6900 - val_accuracy: 0.5152
# Epoch 2/25
# 17/17 [==============================] - 2s 94ms/step - loss: 0.6858 - accuracy: 0.5297 - val_loss: 0.6863 - val_accuracy: 0.5152
# Epoch 3/25
# 17/17 [==============================] - 2s 93ms/step - loss: 0.6820 - accuracy: 0.5562 - val_loss: 0.7077 - val_accuracy: 0.5152
# Epoch 4/25
# 17/17 [==============================] - 2s 94ms/step - loss: 0.6880 - accuracy: 0.5859 - val_loss: 0.6762 - val_accuracy: 0.5671
# Epoch 5/25
# 17/17 [==============================] - 2s 101ms/step - loss: 0.6455 - accuracy: 0.6072 - val_loss: 0.6688 - val_accuracy: 0.5758
# Epoch 6/25
# 17/17 [==============================] - 2s 92ms/step - loss: 0.6033 - accuracy: 0.6573 - val_loss: 0.6667 - val_accuracy: 0.5974
# Epoch 7/25
# 17/17 [==============================] - 2s 92ms/step - loss: 0.5914 - accuracy: 0.6799 - val_loss: 0.6641 - val_accuracy: 0.6104
# Epoch 8/25
# 17/17 [==============================] - 2s 93ms/step - loss: 0.5297 - accuracy: 0.7102 - val_loss: 0.6052 - val_accuracy: 0.6494
# Epoch 9/25
# 17/17 [==============================] - 2s 94ms/step - loss: 0.4804 - accuracy: 0.7860 - val_loss: 0.5643 - val_accuracy: 0.6623
# Epoch 10/25
# 17/17 [==============================] - 2s 92ms/step - loss: 0.4297 - accuracy: 0.8184 - val_loss: 0.5273 - val_accuracy: 0.7359
# Epoch 11/25
# 17/17 [==============================] - 2s 94ms/step - loss: 0.3552 - accuracy: 0.8888 - val_loss: 0.4818 - val_accuracy: 0.7662
# Epoch 12/25
# 17/17 [==============================] - 2s 93ms/step - loss: 0.3072 - accuracy: 0.8930 - val_loss: 0.6085 - val_accuracy: 0.7056
# Epoch 13/25
# 17/17 [==============================] - 2s 94ms/step - loss: 0.3352 - accuracy: 0.8667 - val_loss: 0.5185 - val_accuracy: 0.7316
# Epoch 14/25
# 17/17 [==============================] - 2s 94ms/step - loss: 0.2359 - accuracy: 0.9304 - val_loss: 0.4094 - val_accuracy: 0.8052
# Epoch 15/25
# 17/17 [==============================] - 2s 95ms/step - loss: 0.1736 - accuracy: 0.9629 - val_loss: 0.3962 - val_accuracy: 0.8182
# Epoch 16/25
# 17/17 [==============================] - 2s 93ms/step - loss: 0.1549 - accuracy: 0.9660 - val_loss: 0.4557 - val_accuracy: 0.8052
# Epoch 17/25
# 17/17 [==============================] - 2s 95ms/step - loss: 0.1379 - accuracy: 0.9668 - val_loss: 0.3882 - val_accuracy: 0.8268
# Epoch 18/25
# 17/17 [==============================] - 2s 93ms/step - loss: 0.1050 - accuracy: 0.9800 - val_loss: 0.3810 - val_accuracy: 0.8355
# Epoch 19/25
# 17/17 [==============================] - 2s 93ms/step - loss: 0.0827 - accuracy: 0.9818 - val_loss: 0.3546 - val_accuracy: 0.8528
# Epoch 20/25
# 17/17 [==============================] - 2s 95ms/step - loss: 0.0582 - accuracy: 0.9920 - val_loss: 0.4469 - val_accuracy: 0.8398
# Epoch 21/25
# 17/17 [==============================] - 2s 94ms/step - loss: 0.0497 - accuracy: 0.9998 - val_loss: 0.3646 - val_accuracy: 0.8442
# Epoch 22/25
# 17/17 [==============================] - 2s 95ms/step - loss: 0.0364 - accuracy: 1.0000 - val_loss: 0.3848 - val_accuracy: 0.8442
# Epoch 23/25
# 17/17 [==============================] - 2s 93ms/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.4294 - val_accuracy: 0.8528
# Epoch 24/25
# 17/17 [==============================] - 2s 93ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.3963 - val_accuracy: 0.8442
# Epoch 25/25
# 17/17 [==============================] - 2s 94ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.4024 - val_accuracy: 0.8442
# INFO:tensorflow:Assets written to: Cat_vs_Dog-CNN.model\assets

# %%
import cv2
import tensorflow as tf

class_category = ["Cat", "Dog",]


def prepare(filepath):
    IMG_SIZE = 50  # 50 in txt-based

    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    #new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)


model = tf.keras.models.load_model('Cat_vs_Dog-CNN.model')

prediction = model.predict([prepare('data/validation/cats/12454.jpg')])
print(prediction,'\n')  # will be a list in a list.

print(class_category[int(prediction[0][0])])
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000287045A0DC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[0.]]
#
# Cat
